# %% [markdown]
# <h2>TextRank multiple with TFIDF</h2>

# %%
import pandas as pd
import os
data = pd.read_csv(os.path.join("dataprep1.csv"))
df = data

# %%
word = pd.read_csv(os.path.join("word.csv"))
dfword = word

# %% [markdown]
# <p>TextRank</p>

# %%
from collections import OrderedDict
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('en_core_web_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number=10):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
            print(key+","+str(value))
            if i > number:
                break
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight

# %% [markdown]
# <p>TF-IDF</p>

# %%
from operator import itemgetter
class tfIDF():
    def __init__(self,doc):
        self.doc = [x.split() for x in doc]
        self.wordSet = self.getWordset(self.doc)
        self.wordDict = self.getWorddict(self.doc)
        self.idf = self.computeIDF(self.wordDict)
        self.tfidf = []

    def getWordset(self,doc):
        wordSet = []
        for x in doc:
            wordSet = wordSet + x
        return set(wordSet)

    def getWorddict(self,doc):
        wordDict = []
        for i in range(0,len(doc)):
            wordDict.append(dict.fromkeys(self.wordSet, 0))
        for i in range(0,len(wordDict)):
            for word in doc[i]:
                wordDict[i][word]+=1
        return wordDict

    def computeIDF(self,docList):
        import math
        idfDict = {}
        N = len(docList)

        idfDict = dict.fromkeys(docList[0].keys(), 0)
        for doc in docList:
            for word, val in doc.items():
                if val > 0:
                    idfDict[word] += 1

        for word, val in idfDict.items():
            idfDict[word] = math.log10(N / float(val))

        return idfDict    
    
    def computeTFIDF(self, i, idfs):
        tfidf = {}
        for word in self.doc[i]:
            tfidf[word] = self.wordDict[i][word]*idfs[word]
        return tfidf
    
    def getTFIDF(self):
        idfs = self.idf
        tfidf_out = []
        for x in range(0,len(self.doc)):
            tfidf_out.append(self.computeTFIDF(x, idfs))
        self.tfidf = tfidf_out
        return list(tfidf_out)

    def getSCORE(self):
        score = []
        for u in range(0,len(self.tfidf)):
            score.append(0)
            for i in self.tfidf[u]:
                score[u] += self.tfidf[u][i]
        return score
    
    def getIDF(self):
        return self.idf

    def getWORDSET(self):
        return self.wordSet
    
    def getWORDDICT(self):
        return self.wordDict
    
    def search(self,query):
        query_tfidf = []

        num = 0
        tfidf_out = self.getTFIDF()
        for i in tfidf_out:
            query_tfidf.append(0.0)
            for u in i:
                if u in query:
                    query_tfidf[num] += i[u]
            num = num + 1
        
        hasil = [a*b for a,b in zip(query_tfidf,self.getSCORE())]
        for i in range(0,len(hasil)):
            hasil[i] = [i, hasil[i]]
        
        hasil_akhir = reversed(sorted(hasil, key=itemgetter(1)))
        hasil_akhir = [x for x in hasil_akhir]
# [[137, 185.74624790040363]]
# [[140, 325.60541690614195]]
# [[118, 715.2695737240937]]
# [[140, 221.4092509744852]]
# [[141, 51.77587387679944]]
# [[116, 145.53500852896715]]
# [[143, 156.26834859017322]]
# [[116, 282.92021503478907]]
# [[135, 167.4701017306751]]
# [[128, 494.13004100257325]]
# [[143, 579.4139553080186]]
# [[143, 1204.6969105581595]]
# [[143, 338.0304190894419]]
# [[143, 312.53669718034644]]
# [[143, 579.4139553080186]]
# [[144, 41.190028593763145]]
# [[145, 131.73416153247481]]
# [[15, 73.9936972825433]]
# [[15, 63.811246364497265]]
# [[128, 220.47016033842735]]
# [[146, 40.62382753957647]]
# [[151, 110.78659157467821]]
# [[15, 137.80494364704055]]
# [[116, 799.5713873937684]]
# [[147, 37.02785815810661]]
# [[15, 73.9936972825433]]
# [[89, 127.3569088789032]]
# [[150, 44.93433102602136]]
# [[115, 105.92773277048397]]
# [[149, 23.978400816881678]]
# [[113, 395.2021157075025]]
# [[150, 443.4326414976499]]
# [[150, 44.93433102602136]]
# [[150, 88.68652829952998]]
# [[151, 110.78659157467821]]
# [[128, 138.78302195420667]]
# [[115, 79.13705095335418]]
# [[152, 165.02751158454862]]
# [[152, 165.02751158454862]]
# [[150, 44.93433102602136]]
# [[153, 70.47045185211012]]
# [[153, 81.71552161705155]]
# [[130, 136.16479719956075]]

# %%
tr4w = TextRank4Keyword()
req = 1
for i in range(len(data)):
    print("Requirement", req ,":")
    req=req+1
    tr4w.analyze(df['0'][i], candidate_pos = ['NOUN', 'PROPN'], window_size=4, lower=False)
    tr4w.get_keywords(1)
    print("\n")
# Out:
# Requirement 1 :
# associate,1.281397222222222
# deadline,1.281397222222222
# job,1.0959555555555553
#
#
# Requirement 2 :
# cost,1.281397222222222
# unit,1.281397222222222
# cluster,1.0959555555555553
#
#
# Requirement 3 :
# monitor,1.0814583333333332
# status,1.0814583333333332
# submit,1.0814583333333332
#
#
# Requirement 4 :
# user,1.0
# cancel,1.0
# job,1.0
#
#
# Requirement 5 :
# user,1.0
# check,1.0
# credit,1.0
#
#
# Requirement 6 :
# user,1.0
# check,1.0
# usage,1.0
#
#
# Requirement 7 :
# user,1.0
# check,1.0
# status,1.0
#
#
# Requirement 8 :
# usage,1.1900458333333335
# pattern,1.1900458333333335
# history,1.0044979166666668
#
#
# Requirement 9 :
# check,1.0814583333333332
# status,1.0814583333333332
# submit,1.0814583333333332
#
#
# Requirement 10 :
# user,1.0
# check,1.0
# load,1.0
#
#
# Requirement 11 :
# user,1.0
# alters,1.0
# structure,1.0
#
#
# Requirement 12 :
# user,1.0
# alters,1.0
# policy,1.0
#
#
# Requirement 13 :
# user,1.0
# photo,1.0
# student,1.0
#
#
# Requirement 14 :
# process,1.3603645833333333
# rup,1.0168229166666665
# development,0.81140625
#
#
# Requirement 15 :
# waterfall,1.0
# process,1.0
# model,1.0
#
#
# Requirement 16 :
# product,1.281397222222222
# routine,1.281397222222222
# scheduler,1.0959555555555553
#
#
# Requirement 17 :
# presentation,1.3187027777777778
# deal,1.1386916666666667
# logic,1.1386916666666667
#
#
# Requirement 18 :
# user,1.0814583333333332
# profile,1.0814583333333332
# ride,1.0814583333333332
#
#
# Requirement 19 :
# runtime,1.0
# pattern,1.0
#
#
# Requirement 20 :
# development,1.0
# application,1.0
# server,1.0
#
#
# Requirement 21 :
# application,1.1974479166666665
# server,0.9341840277777776
# cluster,0.9341840277777776
#
#
# Requirement 22 :
# server,1.2714448979591837
# application,0.9614290816326531
# ibm,0.9614290816326531
#
#
# Requirement 23 :
# server,1.4574652777777777
# ibm,1.0312847222222223
# mysql,0.8766319444444444
#
#
# Requirement 24 :
# server,1.4908258503401361
# redundancy,1.1171901360544219
# mirroring,1.1171901360544219
#
#
# Requirement 25 :
# use,1.3187027777777778
# linux,1.1386916666666667
# eclipse,1.1386916666666667
#
#
# Requirement 26 :
# administrator,1.0814583333333332
# student,1.0814583333333332
# account,1.0814583333333332
#
#
# Requirement 27 :
# force,1.1900458333333335
# password,1.1900458333333335
# student,1.0044979166666668
#
#
# Requirement 28 :
# system,1.0
# administrator,1.0
# student,1.0
#
#
# Requirement 29 :
# system,1.1900458333333335
# fill,1.1900458333333335
# detail,1.0044979166666668
#
#
# Requirement 30 :
# detail,1.1900458333333335
# information,1.1900458333333335
# telephone,1.0044979166666668
#
#
# Requirement 31 :
# login,1.1900458333333335
# time,1.1900458333333335
# security,1.0044979166666668
#
#
# Requirement 32 :
# student,1.0
# request,1.0
# heshe,1.0
#
#
# Requirement 33 :
# staff,1.0
# view,1.0
# detail,1.0
#
#
# Requirement 34 :
# unit,1.2967621527777777
# cohort,1.1646453373015873
# change,1.0651835317460316
#
#
# Requirement 35 :
# change,1.3187027777777778
# coordinator,1.1386916666666667
# student,1.1386916666666667
#
#
# Requirement 36 :
# view,1.281397222222222
# student,1.281397222222222
# coordinator,1.0959555555555553
#
#
# Requirement 37 :
# list,1.281397222222222
# employee,1.281397222222222
# coordinator,1.0959555555555553
#
#
# Requirement 38 :
# coordinator,1.1900458333333335
# reset,1.1900458333333335
# student,1.0044979166666668
#
#
# Requirement 39 :
# mail,1.1900458333333335
# server,1.1900458333333335
# course,1.0044979166666668
#
#
# Requirement 40 :
# system,1.0
# administrator,1.0
# student,1.0
#
#
# Requirement 41 :
# administration,1.0
# staff,1.0
# accounting,1.0
#
#
# Requirement 42 :
# administration,1.0
# staff,1.0
# school,1.0
#
#
# Requirement 43 :
# requirement,1.4471747685185181
# analysis,1.2763877314814813
# engineering,1.102
#
#
# Requirement 44 :
# waterfall,1.0
# process,1.0
# model,1.0
#
#
# Requirement 45 :
# team,1.2443513888888886
# subphase,1.0786958333333332
# member,1.0745402777777775
#
#
# Requirement 46 :
# phone,1.2137986111111108
# mitigate,1.2137986111111108
# cell,1.2067152777777777
#
#
# Requirement 47 :
# user,1.0814583333333332
# developer,1.0814583333333332
# requirement,1.0814583333333332
#
#
# Requirement 48 :
# scope,1.5745055555555556
# creep,1.5745055555555556
# project,0.9813944444444446
#
#
# Requirement 49 :
# design,1.0406111111111112
# pattern,1.0406111111111112
# mvc,1.0406111111111112
#
#
# Requirement 50 :
# web,1.281397222222222
# application,1.281397222222222
# patter,1.0959555555555553
#
#
# Requirement 51 :
# administrator,1.0
# client,1.0
# space,1.0
#
#
# Requirement 52 :
# client,1.273511111111111
# administrator,0.8632444444444444
# role,0.8632444444444444
#
#
# Requirement 53 :
# administrator,1.0
# access,1.0
# document,1.0
#
#
# Requirement 54 :
# client,1.0
# administrator,1.0
# view,1.0
#
#
# Requirement 55 :
# administrator,1.0814583333333332
# read,1.0814583333333332
# content,1.0814583333333332
#
#
# Requirement 56 :
# client,1.0
# administrator,1.0
#
#
# Requirement 57 :
# user,1.0
# role,1.0
# time,1.0
#
#
# Requirement 58 :
# user,1.0
# person,1.0
# role,1.0
#
#
# Requirement 59 :
# server,1.3187027777777778
# client,1.1386916666666667
# access,1.1386916666666667
#
#
# Requirement 60 :
# access,1.0814583333333332
# document,1.0814583333333332
# space,1.0814583333333332
#
#
# Requirement 61 :
# user,1.0
# view,1.0
# role,1.0
#
#
# Requirement 62 :
# role,1.0
#
#
# Requirement 63 :
# role,1.1227777777777779
# inherits,0.8772222222222221
#
#
# Requirement 64 :
# role,1.1227777777777779
# person,0.8772222222222221
#
#
# Requirement 65 :
# role,1.0
# document,1.0
# sda,1.0
#
#
# Requirement 66 :
# role,1.0
# right,1.0
#
#
# Requirement 67 :
# administrator,1.0
# limit,1.0
# client,1.0
#
#
# Requirement 68 :
# role,1.273511111111111
# canï¿½t,0.8632444444444444
# document,0.8632444444444444
#
#
# Requirement 69 :
# role,1.2507027777777777
# time,1.0865111111111112
# delegate,1.0865111111111112
#
#
# Requirement 70 :
# log,1.0814583333333332
# assignment,1.0814583333333332
# expiration,1.0814583333333332
#
#
# Requirement 71 :
# delegation,1.2843722222222218
# expiration,1.058272222222222
# role,0.8286777777777777
#
#
# Requirement 72 :
# role,1.273511111111111
# assign,0.8632444444444444
# roleright,0.8632444444444444
#
#
# Requirement 73 :
# role,1.0
#
#
# Requirement 74 :
# role,1.0
#
#
# Requirement 75 :
# role,1.273511111111111
# read,0.8632444444444444
# view,0.8632444444444444
#
#
# Requirement 76 :
# role,1.1227777777777779
# update,0.8772222222222221
#
#
# Requirement 77 :
# role,1.0
#
#
# Requirement 78 :
# role,1.0
#
#
# Requirement 79 :
# role,1.273511111111111
# couple,0.8632444444444444
# person,0.8632444444444444
#
#
# Requirement 80 :
# role,1.1227777777777779
# person,0.8772222222222221
#
#
# Requirement 81 :
# document,1.0858854166666667
# role,1.0513541666666666
# assign,0.8627604166666666
#
#
# Requirement 82 :
# role,1.0
# document,1.0
#
#
# Requirement 83 :
# role,1.2080374999999997
# file,1.0391708333333334
# document,1.0391708333333334
#
#
# Requirement 84 :
# role,1.2080374999999997
# file,1.0391708333333334
# document,1.0391708333333334
#
#
# Requirement 85 :
# role,1.0741625
# update,1.0741625
# file,1.0741625
#
#
# Requirement 86 :
# role,1.2443749999999998
# file,0.9185416666666666
# document,0.9185416666666666
#
#
# Requirement 87 :
# document,1.0
# sda,1.0
# role,1.0
#
#
# Requirement 88 :
# role,1.2443749999999998
# document,0.9185416666666666
# hand,0.9185416666666666
#
#
# Requirement 89 :
# user,1.2843722222222218
# start,1.058272222222222
# chat,0.8286777777777777
#
#
# Requirement 90 :
# subphase,1.4943101757369615
# leader,1.24148914399093
# progress,1.087052239229025
#
#
# Requirement 91 :
# documentation,1.3764555555555553
# project,1.0977263888888888
# document,0.9189902777777778
#
#
# Requirement 92 :
# project,1.27890625
# overview,0.9999999999999999
# organization,0.72109375
#
#
# Requirement 93 :
# design,1.0406111111111112
# pattern,1.0406111111111112
# mvc,1.0406111111111112
#
#
# Requirement 94 :
# web,1.281397222222222
# application,1.281397222222222
# patter,1.0959555555555553
#
#
# Requirement 95 :
# functionality,1.1774375
# search,1.1774375
# system,1.1770833333333335
#
#
# Requirement 96 :
# user,1.0814583333333332
# profile,1.0814583333333332
# ride,1.0814583333333332
#
#
# Requirement 97 :
# runtime,1.0
# pattern,1.0
#
#
# Requirement 98 :
# server,1.3603645833333333
# development,1.0168229166666665
# deployment,0.81140625
#
#
# Requirement 99 :
# server,1.27890625
# deployment,0.9999999999999999
# replacement,0.72109375
#
#
# Requirement 100 :
# workstation,1.4432749999999999
# case,1.1449249999999997
# development,0.7059
#
#
# Requirement 101 :
# user,1.0
# information,1.0
# sgp,1.0
#
#
# Requirement 102 :
# user,1.0
# sgp,1.0
#
#
# Requirement 103 :
# application,1.0814583333333332
# update,1.0814583333333332
# form,1.0814583333333332
#
#
# Requirement 104 :
# user,1.0
# update,1.0
# data,1.0
#
#
# Requirement 105 :
# user,1.0
# upload,1.0
# application,1.0
#
#
# Requirement 106 :
# user,1.0
# proficiency,1.0
# test,1.0
#
#
# Requirement 107 :
# project,1.27890625
# overview,0.9999999999999999
# organization,0.72109375
#
#
# Requirement 108 :
# organization,1.3187027777777778
# project,1.1386916666666667
# element,1.1386916666666667
#
#
# Requirement 109 :
# organization,1.0814583333333332
# process,1.0814583333333332
# document,1.0814583333333332
#
#
# Requirement 110 :
# risk,1.0
# management,1.0
# section,1.0
#
#
# Requirement 111 :
# design,1.0406111111111112
# pattern,1.0406111111111112
# mvc,1.0406111111111112
#
#
# Requirement 112 :
# web,1.281397222222222
# application,1.281397222222222
# patter,1.0959555555555553
#
#
# Requirement 113 :
# staff,1.948968923611111
# login,1.3201223958333332
# log,1.2485187500000001
#
#
# Requirement 114 :
# template,1.9204284135736058
# display,1.8072046134421136
# staff,1.6327812133913095
#
#
# Requirement 115 :
# report,1.8724109029147495
# permission,1.3472680309007234
# system,1.240667170721017
#
#
# Requirement 116 :
# staff,1.6284449003928172
# query,1.4952415649551063
# value,1.309198530443322
#
#
# Requirement 117 :
# report,2.494998681543324
# patron,1.6641487860203767
# statistic,1.5498794879062734
#
#
# Requirement 118 :
# privacy,1.3187027777777778
# patron,1.1386916666666667
# state,1.1386916666666667
#
#
# Requirement 119 :
# item,2.771516578118851
# record,1.5432221713892167
# hold,1.3488959809130265
#
#
# Requirement 120 :
# system,1.0
# query,1.0
# selection,1.0
#
#
# Requirement 121 :
# report,1.4432749999999999
# queue,1.1449249999999997
# ability,0.7059
#
#
# Requirement 122 :
# system,1.0
# definition,1.0
# appendix,1.0
#
#
# Requirement 123 :
# support,1.0814583333333332
# report,1.0814583333333332
# requirement,1.0814583333333332
#
#
# Requirement 124 :
# book,1.35372287414966
# predict,1.171737103174603
# patron,1.144071626984127
#
#
# Requirement 125 :
# item,1.8539681523998488
# number,1.601515060468632
# library,1.397273046579743
#
#
# Requirement 126 :
# interface,1.0814583333333332
# capacity,1.0814583333333332
# branch,1.0814583333333332
#
#
# Requirement 127 :
# percentage,1.7215379935720843
# ability,1.675676629935721
# genreformat,1.086557943067034
#
#
# Requirement 128 :
# ability,1.6822331688093053
# material,1.6415370663707787
# book,1.347093046627895
#
#
# Requirement 129 :
# item,2.297237359297366
# ability,2.038495264476982
# location,1.8697564173591874
#
#
# Requirement 130 :
# report,1.483009910005669
# transit,1.3013323483560093
# system,1.2431929386337868
#
#
# Requirement 131 :
# item,2.1374174054730375
# system,2.1204204527348414
# copy,1.6906041752623135
#
#
# Requirement 132 :
# record,2.066384027777777
# deletion,1.1249145833333332
# patron,1.1166152777777776
#
#
# Requirement 133 :
# patron,1.7066805555555553
# characteristic,1.0755555555555554
# branch,1.0755555555555554
#
#
# Requirement 134 :
# system,1.5689884259259257
# list,1.114395833333333
# activity,1.087675925925926
#
#
# Requirement 135 :
# transaction,1.0
# history,1.0
# day,1.0
#
#
# Requirement 136 :
# transaction,2.106818055555556
# checkins,0.971123611111111
# branch,0.9697069444444444
#
#
# Requirement 137 :
# checkin,1.3187027777777778
# type,1.1386916666666667
# bookdrop,1.1386916666666667
#
#
# Requirement 138 :
# checkout,1.7504282578217238
# renewal,1.1998085922127113
# staff,1.1736370554161746
#
#
# Requirement 139 :
# hold,1.281397222222222
# staff,1.281397222222222
# request,1.0959555555555553
#
#
# Requirement 140 :
# hold,2.0101219371747776
# system,1.5067410975283133
# checkout,1.2694691962235995
#
#
# Requirement 141 :
# value,1.8668286850415097
# item,1.7904782765034386
# collection,1.395766425854088
#
#
# Requirement 142 :
# practice,1.281397222222222
# state,1.281397222222222
# accounting,1.0959555555555553
#
#
# Requirement 143 :
# patron,1.9852916666666665
# transaction,1.10678125
# query,1.0574340277777776
#
#
# Requirement 144 :
# charge,1.514946889726743
# period,1.4479203898817907
# time,1.4445754824743835
#
#
# Requirement 145 :
# payment,1.5677002551020407
# charge,1.1596713435374149
# ledger,0.9696392431972789
#
#
# Requirement 146 :
# function,1.2931555555555554
# mockup,1.1703204365079363
# phase,1.0191789682539683
#
#
# Requirement 147 :
# programming,1.3187027777777778
# knowledge,1.1386916666666667
# software,1.1386916666666667
#
#
# Requirement 148 :
# subphase,1.1317027777777777
# person,1.1317027777777777
# work,1.1317027777777777
#
#
# Requirement 149 :
# minute,1.250513888888889
# meeting,1.243076388888889
# project,1.243076388888889
#
#
# Requirement 150 :
# table,1.0
# content,1.0
# template,1.0
#
#
# Requirement 151 :
# diagram,2.888503401360544
# project,0.9804244614512471
# kaos,0.9804244614512471
#
#
# Requirement 152 :
# software,1.2154336203231293
# change,1.1495173611111111
# control,1.1123551587301588
#
#
# Requirement 153 :
# scope,1.5745055555555556
# creep,1.5745055555555556
# project,0.9813944444444446
#
#
# Requirement 154 :
# android,1.221
# google,1.2133854166666667
# phone,1.2133854166666667
